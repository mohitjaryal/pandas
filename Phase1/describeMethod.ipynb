# %% [markdown]
# # Describe method in pandas

# %%
import pandas as pd

# %%
# creating data frames

data = {
    'Name' : ['ram','shayam','rohit','virat','aditi','raj','driti','simran'],
    'Age' : [20,23,34,26,21,34,29,31],
    'Salary' : [50000,60000,76000,65000,64000,90000,56000,87000],
    'Performance Score' : [85,90,95,94,89,29,99,100]
}

# %%
df = pd.DataFrame(data)

print('Sample Dataframe :\n')
print(df)

print('Descriptive Statistics :\n')
print(df.describe())
# Out:
# Sample Dataframe :
#
#      Name  Age  Salary  Performance Score
# 0     ram   20   50000                 85
# 1  shayam   23   60000                 90
# 2   rohit   34   76000                 95
# 3   virat   26   65000                 94
# 4   aditi   21   64000                 89
# 5     raj   34   90000                 29
# 6   driti   29   56000                 99
# 7  simran   31   87000                100
# Descriptive Statistics :
#
#              Age        Salary  Performance Score
# count   8.000000      8.000000           8.000000
# mean   27.250000  68500.000000          85.125000
# std     5.599745  14461.772268          23.234442
# min    20.000000  50000.000000          29.000000
# 25%    22.500000  59000.000000          88.000000
# 50%    27.500000  64500.000000          92.000000
# 75%    31.750000  78750.000000          96.000000
# max    34.000000  90000.000000         100.000000
