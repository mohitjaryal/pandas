# %% [markdown]
# # Data Frames Methods

# %%
import numpy as np
import pandas as pd

# %%
# importing data sets
ipl = pd.read_csv('data/ipl-matches.csv')

vk = pd.read_csv('data/kohli_ipl.csv')

movies = pd.read_csv('data/movies.csv')

subs = pd.read_csv('data/subs.csv')

batsman = pd.read_csv('data/batsman_runs_ipl.csv')

# %%
# value_counts() -> applicable in both series and data frame

# making a data frame
marks = pd.DataFrame([
    [100,54,23],
    [89,64,45],
    [66,75,64],
    [89,64,45],
    [89,64,45],
    [90,100,89],
    [90,100,89],
    [89,64,45],
    [90,100,89]
],columns=['iq','maks','package'])

marks
# Out:
#     iq  maks  package
# 0  100    54       23
# 1   89    64       45
# 2   66    75       64
# 3   89    64       45
# 4   89    64       45
# 5   90   100       89
# 6   90   100       89
# 7   89    64       45
# 8   90   100       89

# %%
# value_counts() -> applicable in both series and data frame
# value_counts method counts how many rows in a data frame and frequency of the repetation of those rows
marks.value_counts()
# Out:
# iq   maks  package
# 89   64    45         4
# 90   100   89         3
# 100  54    23         1
# 66   75    64         1
# Name: count, dtype: int64

# %%
# find which player has won the most potm (man of the match) in finals and semi finals
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# KA Pollard           3
# SK Raina             3
# JJ Bumrah            2
# SR Watson            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# YK Pathan            2
# A Kumble             2
# HH Pandya            1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# KH Pandya            1
# KV Sharma            1
# NM Coulter-Nile      1
# Washington Sundar    1
# BCJ Cutting          1
# DA Warner            1
# MC Henriques         1
# RG Sharma            1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# Harbhajan Singh      1
# BJ Hodge             1
# MEK Hussey           1
# MS Bisla             1
# ...

# %%
# counts how many times each toss decision (bat/field) occurs
ipl['TossDecision'].value_counts()
# Out:
# TossDecision
# field    599
# bat      351
# Name: count, dtype: int64

# %%
# how many matches each team has played
ipl['Team1'].value_counts() + ipl['Team2'].value_counts()
# Out:
# Team1
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %%
# sort_values() -> works with both series and data frame

# working with movies data set

# performing sort_value() in single column

# sort the moves based on their names
movies.sort_values(['title_x'])

# if we'll perform sort_values() in nan values (missing values) it will put all the missing values at the end
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# multiple column

movies.sort_values(['year_of_release','title_x'])
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# sort movies name in descending order and year of release in ascending

movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# rank -> it only work with series 
# rank() in a pandas DataFrame assigns a numerical position to each value based on its order compared to others (smallest to largest or vice versa)

# by batsman['batting_rank'] = this we created a new column 
batsman['batting_rank']=batsman['batsman_run'].rank(ascending=False)
batsman.head(5)
# Out:
#            batter  batsman_run  batting_rank
# 0  A Ashish Reddy          280         166.5
# 1        A Badoni          161         226.0
# 2      A Chandila            4         535.0
# 3        A Chopra           53         329.0
# 4     A Choudhary           25         402.5

# %%
# sort_index() -> works with both series and data frame
# it sort the index

marks = {
    'math':100,
    'science':99,
    'hindi':96,
    'cs':98
}

# making a series
marks_series = pd.Series(marks)
marks_series

# sorting a series
# it will do sort in alphabetical order
marks_series.sort_index()
# Out:
# cs          98
# hindi       96
# math       100
# science     99
# dtype: int64

# %%
# sorting a data frame

# working with movies data set
movies.sort_index(ascending=False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# set_index() -> only works with data frame
# used to make one or more columns the index (row labels) of the DataFrame

# here we are making the name of the batsman (batter) the name of our index
batsman.set_index('batter',inplace=True)
batsman
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
# reset_index() -> it works with both series and data frame
# it is used to convert the index back into a normal column and replace it with a default numeric index.
batsman.reset_index()
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
# now replace existing index without loosing it
# firstly reset it and then make a new index

batsman.reset_index().set_index('batting_rank')
# Out:
#                       batter  batsman_run
# batting_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
# if we'll use reset_index() in a series -> it will become a data frame
type(marks_series.reset_index())
# Out:
# pandas.DataFrame

# %%
# rename -> only works in data frame
# used to rename a column


# converting columns names
movies.rename(columns={'imdb_id':'imdb','poster_path':'link'},inplace=True)
movies

# we can also rename the index name using rename
# use this -> movies.rename(index={'Uri: The Surgical Strike':'uri','Battalion 609':'Battalion'})
# Out:
#                                    title_x        imdb  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                                    link  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# unique -> works with series only
# it gives all the unique values from a particulat series

# unique counts nan values 
# check seasons (ipl)
ipl['Season'].unique()
# Out:
# <StringArray>
# [   '2022',    '2021', '2020/21',    '2019',    '2018',    '2017',    '2016',
#     '2015',    '2014',    '2013',    '2012',    '2011', '2009/10',    '2009',
#  '2007/08']
# Length: 15, dtype: str

# %%
# nunique -> works with both data frame and seies
# it tells number of unique values

# one important thing -> nunique() dosen't count nan values 
ipl['Season'].nunique()
# Out:
# 15

# %%
#  isnull -> works with both data frame and series

student_dict = {
    'name':['mohit','rishabh','rohit','ram','shayam','shayam'],
    'iq':[100,90,98,np.nan,34,34],
    'marks' : [87,43,65,90,np.nan,np.nan],
    'package':[90,54,32,89,34,34]
}
students = pd.DataFrame(student_dict)
students
# Out:
#       name     iq  marks  package
# 0    mohit  100.0   87.0       90
# 1  rishabh   90.0   43.0       54
# 2    rohit   98.0   65.0       32
# 3      ram    NaN   90.0       89
# 4   shayam   34.0    NaN       34
# 5   shayam   34.0    NaN       34

# %%
# isnull (on students data frame)

# checking is there any missing value in student data set(in name column)
students['name'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: name, dtype: bool

# %%
# notnull -> works with both series and data frame
# it is opposite from isnull -> if there is missing value it will say False and if not then True
students['name'].notnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# Name: name, dtype: bool

# %%
# hasnans -> works with series
# it will tell is there any missing value in column or not
students['name'].hasnans
# Out:
# False

# %%
# dropna -> works with both series and data frame
# it will remove the entire row which have missing value
students.dropna()
# Out:
#       name     iq  marks  package
# 0    mohit  100.0   87.0       90
# 1  rishabh   90.0   43.0       54
# 2    rohit   98.0   65.0       32

# %%
# removing only those columns which have all missing values
students.dropna(how='all')
# Out:
#       name     iq  marks  package
# 0    mohit  100.0   87.0       90
# 1  rishabh   90.0   43.0       54
# 2    rohit   98.0   65.0       32
# 3      ram    NaN   90.0       89
# 4   shayam   34.0    NaN       34

# %%
# fillna -> works with both series and data frame
# fill the missing values

# filled every missing value with unknown
students.fillna('0')
# Out:
#       name     iq marks  package
# 0    mohit  100.0  87.0       90
# 1  rishabh   90.0  43.0       54
# 2    rohit   98.0  65.0       32
# 3      ram      0  90.0       89
# 4   shayam   34.0     0       34

# %%
# drop_duplicates -> works with both series and data frame
# helps to drop the duplicated rows

# we can use .drop_duplicates(keep='first / last) by default it's first -> means it will keep the first appearance and frop the last one and vice versafit
students.drop_duplicates()
# Out:
#       name     iq  marks  package
# 0    mohit  100.0   87.0       90
# 1  rishabh   90.0   43.0       54
# 2    rohit   98.0   65.0       32
# 3      ram    NaN   90.0       89
# 4   shayam   34.0    NaN       34

# %%
# find the last match played by virat kohli in Delhi

ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field  ...
#
#         WinningTeam    WonBy Margin  method Player_of_Match  \
# 0    Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1  Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1  \
# ...

# %%
# find the last match played by virat kohli in Delhi

# creating a function
def did_kohli_play(player_list):
    return 'V Kohli' in player_list


ipl['did_kohli_play'] = ipl['all_players'].apply(did_kohli_play)
ipl[(ipl['City'] == 'Delhi') & (ipl['did_kohli_play'] == True)].drop_duplicates(subset=['City','did_kohli_play'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_kohli_play
# 208           True
#
# [1 rows x 22 columns]

# %%
# drop -> works with both series and data frame
# used to drop rows and columns

# drop marks and iq columns
students.drop(columns=['marks','iq'])
# Out:
#       name  package
# 0    mohit       90
# 1  rishabh       54
# 2    rohit       32
# 3      ram       89
# 4   shayam       34
# 5   shayam       34

# %%
# drop shayam (4th index) and rohit row
students.drop(index=[2,4])
# Out:
#       name     iq  marks  package
# 0    mohit  100.0   87.0       90
# 1  rishabh   90.0   43.0       54
# 3      ram    NaN   90.0       89
# 5   shayam   34.0    NaN       34

# %%
# apply -> works both in series and data frame
# find euclidean distance
points_df = pd.DataFrame({
    '1st point':[(3,4),(-6,5),(7,8),(-2,9),(4,5)],
    '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)],
})
points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (7, 8)    (2, 2)
# 3   (-2, 9)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def euclidean(row):
    pt_A = row['1st point']
    pt_B = row['2nd point']

    return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

points_df['distance']=points_df.apply(euclidean,axis=1)
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (7, 8)    (2, 2)   7.810250
# 3   (-2, 9)  (10, 10)  12.041595
# 4    (4, 5)    (1, 1)   5.000000
