# %% [markdown]
# # right merging  (joining)

# %%
import pandas as pd

# data frame 1 - customers_detail
customers_detail = pd.DataFrame({
    'name' : ['ramesh','suresh','mahesh','rajesh'],
    'year' : [2024,2024,2024,2024],
    'id' : [1,2,3,4]
})

# data frame 2 - orders
orders = pd.DataFrame({
    'id' : [8,9,1,4],
    'amount' : [100,200,900,189]
})

# merging

merged = pd.merge(customers_detail,orders, on='id',how='right')
print('Right joined :\n',merged)
# Out:
# Right joined :
#       name    year  id  amount
# 0     NaN     NaN   8     100
# 1     NaN     NaN   9     200
# 2  ramesh  2024.0   1     900
# 3  rajesh  2024.0   4     189
